# %% [markdown]
# # Backpropagation and the MLP
# From: https://rolisz.ro/2013/04/18/neural-networks-in-python/

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl

# %% [markdown]
# ## The Dataset
# The following script allows you to create a 2D dataset by using the mouse. The left click adds points belonging to class A (blue), and the right click adds points belonging to class B (red). You can create as many points as you desire. The final dataset will contain hence three values per point: x coordinate (-1 ≤ x ≤ 1), y coordinate (-1 ≤ y ≤ 1) and the class ∈ {1,-1}.

# %%
# %matplotlib notebook

fig = pl.figure(figsize=(6,6))
pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

dataset = []

def onclick(event):
    global dataset
    cx = event.xdata
    cy = event.ydata
    co = event.button
    dataset.append((cx, cy, co-2))

    pl.scatter(cx, cy, c=(['b', 'r'])[co > 2], s=100, lw=0)
    pl.grid(True)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig.canvas.mpl_disconnect(onclick)

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
dataset
# Out:
# array([[-0.93548391,  0.84304631, -1.        ],
#        [-0.97849467,  0.53399554, -1.        ],
#        [-0.91397854,  0.28381158, -1.        ],
#        [-0.60573481,  0.17343631, -1.        ],
#        [-0.52688176,  0.48248708, -1.        ],
#        [-0.72759861,  0.64437082, -1.        ],
#        [-0.82078857,  0.7988962 , -1.        ],
#        [-0.70609323,  0.54135389, -1.        ],
#        [-0.72043015,  0.51192048, -1.        ],
#        [ 0.69892469, -0.64334074, -1.        ],
#        [ 0.34050175, -0.57711557, -1.        ],
#        [ 0.46236555, -0.8935247 , -1.        ],
#        [ 0.7491039 , -0.84937459, -1.        ],
#        [ 0.81362003, -0.56975722, -1.        ],
#        [ 0.68458777, -0.31221491, -1.        ],
#        [ 0.3835125 , -0.55504052, -1.        ],
#        [ 0.62007164, -0.59183227, -1.        ],
#        [ 0.68458777, -0.47409865, -1.        ],
#        [ 0.59139781,  0.83568796, -1.        ],
#        [ 0.36917558,  0.74002939, -1.        ],
#        [ 0.46953401,  0.43833697, -1.        ],
#        [ 0.72759852,  0.3426784 , -1.        ],
#        [ 0.79211465,  0.71795433, -1.        ],
#        [ 0.51971322,  0.7841795 , -1.        ],
#        [ 0.64157702,  0.5560706 , -1.        ],
#        [ 0.70609315,  0.57814565, -1.        ],
#        [ 0.62007164,  0.65908752, -1.        ],
#        [ 0.44086017,  0.90191313, -1.        ],
#        [-0.86379933, -0.2827815 ,  1.        ],
#        [-0.89247316, -0.81994118,  1.        ],
#        [-0.46236564, -0.81994118,  1.        ],
#        [-0.42652334, -0.67277414,  1.        ],
#        [-0.78494628, -0.45202359,  1.        ],
#        [-0.5555556 , -0.31221491,  1.        ],
#        [-0.38351259, -0.65805744,  1.        ],
#        [-0.18279574, -0.62126568,  1.        ],
#        [-0.26881725, -0.33428996,  1.        ],
#        [-0.44086026, -0.33428996,  1.        ],
#        [-0.21146958,  0.88719642,  1.        ],
#        [-0.19713266,  0.75474609,  1.        ],
#        [-0.07526886,  0.43833697,  1.        ],
#        [-0.01075273,  0.1440029 ,  1.        ],
#        [ 0.01075264,  0.04098597,  1.        ],
#        [-0.13261653,  0.33532004,  1.        ],
#        [-0.08243732,  0.585504  ,  1.        ],
#        [-0.08243732,  0.74002939,  1.        ],
#        [-0.0681004 ,  0.92398818,  1.        ],
#        [ 0.15412182,  0.7694628 ,  1.        ],
#        [ 0.1756272 ,  0.95342159,  1.        ],
#        [-0.03225811,  0.9975717 ,  1.        ],
#        [-0.36200721,  0.96813829,  1.        ],
#        [-0.45519718,  0.93870489,  1.        ],
#        [-0.42652334,  0.76210444,  1.        ],
#        [ 0.36200712,  0.04098597,  1.        ],
#        [ 0.61290318,  0.01155257,  1.        ],
#        [ 0.78494619,  0.03362762,  1.        ],
#        [ 0.90680999,  0.18079466,  1.        ],
#        [ 0.96415766, -0.0546726 ,  1.        ],
#        [ 0.93548383, -0.12089776,  1.        ],
#        [ 0.89964153,  0.1587196 ,  1.        ],
#        [ 0.49820784,  0.05570268,  1.        ],
#        [ 0.39068096, -0.13561447,  1.        ],
#        [ 0.13261644, -0.29013985,  1.        ],
#        [ 0.37634404, -0.13561447,  1.        ],
#        [ 0.20430103, -0.17976458,  1.        ],
#        [ 0.20430103, -0.17976458,  1.        ],
#        [ 0.24014333,  0.04098597,  1.        ],
#        [ 0.25448024,  0.24701982,  1.        ],
#        [-0.16129037,  0.07777773, -1.        ],
#        [-0.15412191, -0.0693893 , -1.        ],
#        [-0.18279574,  0.07041938, -1.        ],
#        [-0.13978499, -0.0546726 , -1.        ],
#        [-0.02508965, -0.25334809, -1.        ]])

# %% [markdown]
# ## The MLP
# The class presented here was adapted from the code found at: https://rolisz.ro/2013/04/18/neural-networks-in-python/
#
# The class implements a MLP with a fully configurable number of layers and neurons. It adapts its weights using the backpropagation algorithm in an online manner.

# %%
import mlp_backprop_momentum as mlp
# %matplotlib inline

# %% [markdown]
# ## Learning
# Let use the MLP class to solve a classification problem

# %% [markdown]
# ### Create the MLP

# %%
input_data = dataset[:,0:2]
output_data = dataset[:,2]
nn = mlp.MLP([2,5,1], 'tanh')
# 2 inputs
# 2 hidden nodes
# 1 output

# %% [markdown]
# ### Use backpropagation to find the network parameters

# %%
MSE = nn.fit((input_data, output_data), learning_rate=0.001, momentum=0.9, epochs=1000)

# %%
# plot the error through the iterations of the algorithm
pl.figure(figsize=(15,4))
pl.plot(MSE)
pl.ylabel('Error (MSE)')
pl.xlabel('Epochs')
pl.title('Mean Squared Error through epochs')
pl.grid()

# %% [markdown]
# ## Testing
# Now, let's use the trained network to predict the classes in the dataset.
# This section shows three different manners of showing the outputs of the network, and how to compare its output with the targets to evaluate the performance of the classification.

# %% [markdown]
# ### Compute the output of the network

# %%
output = nn.compute_output(input_data)

# %%
output.shape
# Out:
# (73, 1)

# %% [markdown]
# ### Plot boxplots of the output

# %%
pl.figure(figsize=(8,6))
pl.boxplot([output[output_data==-1.0,0], output[output_data==1.0,0]])
pl.xticks([1, 2], ['A', 'B'])
pl.xlabel('Targets')
pl.ylabel('MLP output')
pl.title("Distribution of the network's output wrt the target")
pl.grid()

# %% [markdown]
# ### Plot the output of the network in the space of features (2D)

# %%
input_x = np.arange(-1.2, 1.2, 0.1)
input_y = np.arange(-1.2, 1.2, 0.1)
input_x_matrix, input_y_matrix = np.meshgrid(input_x, input_y)
inputs_xy = np.concatenate((input_x_matrix.flatten()[:,np.newaxis], input_y_matrix.flatten()[:,np.newaxis]), axis=1)

output_values = nn.compute_output(inputs_xy)
output_matrix = np.reshape(output_values, input_x_matrix.shape)

pl.figure(figsize=(8,8))
pl.imshow(np.flipud(output_matrix), interpolation='None', extent=(-1.2,1.2,-1.2,1.2))
pl.scatter(input_data[:,0], input_data[:,1], c=[(['b', 'r'])[int(d>0)] for d in output_data], s=100)
pl.title('Continuous network output and targets');

# %% [markdown]
# ### Plot targets and predicted outputs separately

# %%
pl.figure(figsize=(12,5))
pl.subplot(1,2,1)
pl.scatter(input_data[:,0], input_data[:,1], c=[(['b', 'r'])[int(d>0)] for d in output_data], s=100)
pl.xlim(-1.2, 1.2)
pl.ylim(-1.2, 1.2)
pl.grid()
pl.title('Targets')
pl.subplot(1,2,2)
pl.scatter(input_data[:,0], input_data[:,1], c=[(['b', 'r'])[int(d>0)] for d in output[:,0]], s=100)
pl.xlim(-1.2, 1.2)
pl.ylim(-1.2, 1.2)
pl.grid()
pl.title('MLP output');
